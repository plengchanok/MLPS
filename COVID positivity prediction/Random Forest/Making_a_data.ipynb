# %% [markdown]
# # Phase II: Data Exploration and Analysis

# %% [markdown]
# # 1. Data Cleaning and Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('covidcast_new.csv')
df.head()
# Out:
#   time_value  geo_value  smoothed_wspent_time_1d  smoothed_wtested_14d  \
# 0   1/7/2021       1000                34.412959             12.541558
# 1   1/7/2021       1003                32.814153             10.189340
# 2   1/7/2021       1015                35.621311             14.591271
# 3   1/7/2021       1051                40.453615             14.164503
# 4   1/7/2021       1069                39.228766             10.103564
#
#    smoothed_wpublic_transit_1d  smoothed_wworried_become_ill  \
# 0                     1.464798                     65.771681
# 1                     1.270183                     61.516584
# 2                     6.594649                           NaN
# 3                     3.320922                     68.718538
# 4                     0.288897                     59.961036
#
#    smoothed_wvaccine_likely_govt_health  smoothed_wshop_1d  \
# 0                             22.086274          52.854667
# 1                             25.179399          51.160278
# 2                                   NaN          54.503711
# 3                             19.438763          54.948755
# 4                             23.065494          60.118290
#
#    smoothed_wtested_positive_14d  smoothed_wwork_outside_home_1d  \
# 0                      29.288429                       30.487852
# 1                            NaN                       28.384842
# 2                            NaN                       37.003522
# 3                            NaN                       37.637900
# 4                            NaN                       36.156326
#
#    smoothed_wothers_masked  smoothed_wcli  smoothed_wcovid_vaccinated  \
# 0                57.334785       3.244379                      2.6382
# 1                53.172285       1.199572                         NaN
# 2                      NaN       3.890709                         NaN
# 3                67.550815       3.284647                         NaN
# 4                55.995745       1.881970                         NaN
#
#    smoothed_wvaccine_likely_friends  smoothed_wrestaurant_1d  \
# 0                         28.469582                18.571266
# 1                         27.532881                23.406516
# 2                               NaN                20.974363
# 3                         30.223647                20.009477
# 4                         30.806929                16.574756
#
#    smoothed_wvaccine_likely_politicians  smoothed_wvaccine_likely_who  \
# 0                              9.482316                     24.962112
# 1                              8.933682                     28.864558
# 2                                   NaN                           NaN
# 3                              7.570250                     26.494057
# 4                             12.916249                     24.747620
#
#    smoothed_wwearing_mask  smoothed_wlarge_event_1d
# 0               84.311759                 12.627098
# 1               82.778220                 11.727249
# 2                     NaN                 13.255336
# 3               86.587182                 13.823318
# 4               85.825453                 10.258936

# %%
unique_geo_values = df['geo_value'].unique()
print(unique_geo_values)
# Out:
# [ 1000  1003  1015  1051  1069  1073  1081  1083  1089  1095  1097  1101
#   1103  1117  1125  2000  2020  2090  2170  4000  4003  4013  4015  4019
#   4021  4025  4027  5000  5007  5031  5045  5051  5119  5125  5131  5143
#   6000  6001  6007  6013  6017  6019  6023  6025  6029  6031  6033  6037
#   6039  6041  6045  6047  6053  6055  6057  6059  6061  6065  6067  6071
#   6073  6075  6077  6079  6081  6083  6085  6087  6089  6095  6097  6099
#   6107  6111  6113  8000  8001  8005  8013  8031  8035  8041  8045  8059
#   8069  8077  8101  8123  9000  9001  9003  9005  9007  9009  9011  9013
#   9015 10000 10001 10003 10005 11001 12000 12001 12005 12009 12011 12015
#  12017 12019 12021 12031 12033 12035 12053 12055 12057 12061 12069 12071
#  12073 12081 12083 12085 12086 12091 12095 12097 12099 12101 12103 12105
#  12109 12111 12113 12115 12117 12119 12127 12131 13000 13021 13051 13057
#  13063 13067 13073 13077 13089 13115 13117 13121 13135 13139 13151 13153
#  13185 13215 13223 13245 15000 15001 15003 15009 16000 16001 16005 16019
#  16027 16055 16083 17000 17019 17031 17037 17043 17089 17091 17093 17097
#  17099 17111 17113 17115 17119 17143 17161 17163 17167 17179 17183 17197
#  17201 18000 18003 18019 18035 18039 18043 18057 18063 18081 18085 18089
#  18091 18095 18097 18105 18127 18141 18157 18163 18167 18173 19000 19013
#  19049 19061 19103 19113 19153 19155 19163 19169 19193 20000 20015 20045
#  20091 20161 20173 20177 20209 21000 21015 21019 21037 21059 21067 21093
#  21111 21117 21145 22000 22005 22015 22017 22019 22033 22051 22055 22057
#  22063 22071 22073 22079 22103 22105 22109 23000 23001 23003 23005 23009
#  23011 23017 23019 23031 24000 24003 24005 24013 24015 24021 24025 24027
#  24031 24033 24043 24045 24047 24510 25000 25001 25003 25005 25009 25011
#  25013 25015 25017 25021 25023 25025 25027 26000 26005 26017 26021 26025
#  26037 26045 26049 26065 26073 26075 26077 26081 26087 26091 26093 26099
#  26103 26111 26115 26121 26125 26139 26145 26147 26155 26159 26161 26163
#  27000 27003 27037 27053 27109 27123 27137 27145 27163 28000 28033 28047
#  28049 28059 28081 28089 28121 29000 29019 29031 29043 29047 29077 29095
#  29097 29099 29165 29183 29189 29510 30000 30013 30029 30031 30049 30063
#  30111 31000 31055 31109 31153 32000 32003 32031 33000 33001 33005 33009
#  33011 33013 33015 33017 34000 34001 34003 34005 34007 34013 34015 34017
#  34019 34021 34023 34025 34027 34029 34031 34035 34037 34039 34041 35000
#  35001 35013 35035 35043 35049 36000 36001 36005 36007 36009 36011 36013
#  36015 36019 36027 36029 36045 36047 36053 36055 36059 36061 36063 36065
#  36067 36069 36071 36075 36079 36081 36083 36085 36087 36089 36091 36093
#  36101 36103 36109 36111 36117 36119 37000 37001 37019 37021 37023 37025
#  37027 37031 37035 37049 37051 37057 37063 37067 37071 37081 37085 37087
#  37089 37097 37101 37119 37125 37129 37133 37135 37147 37151 37155 37157
#  37159 37179 37183 37191 37193 38000 38017 39000 39003 39007 39017 39023
#  39025 39029 39035 39041 39045 39049 39057 39061 39063 39085 39087 39089
#  39093 39095 39099 39103 39109 39113 39133 39151 39153 39155 39157 39165
#  39169 39173 40000 40017 40027 40031 40101 40109 40119 40131 40143 40145
#  41000 41003 41005 41011 41017 41019 41029 41033 41035 41039 41043 41047
#  41051 41053 41067 42000 42001 42003 42007 42011 42013 42017 42019 42021
#  42025 42027 42029 42033 42039 42041 42043 42045 42049 42051 42055 42069
#  42071 42073 42075 42077 42079 42081 42085 42089 42091 42095 42097 42101
#  42107 42111 42125 42129 42133 44000 44003 44005 44007 44009 45000 45003
#  45007 45013 45015 45019 45035 45041 45043 45045 45047 45051 45059 45063
#  45073 45075 45077 45079 45083 45085 45091 46000 46099 46103 47000 47001
#  47009 47011 47037 47059 47063 47065 47089 47093 47105 47113 47125 47149
#  47155 47157 47163 47165 47179 47187 47189 48000 48021 48027 48029 48037
#  48039 48041 48061 48085 48091 48099 48113 48121 48135 48139 48141 48157
#  48167 48181 48183 48187 48201 48209 48215 48245 48251 48303 48309 48329
#  48339 48355 48361 48367 48375 48381 48423 48439 48441 48451 48453 48469
#  48479 48485 48491 49000 49005 49011 49035 49049 49053 49057 50000 50007
#  50021 50023 50027 51000 51003 51013 51015 51019 51041 51059 51069 51085
#  51087 51095 51107 51121 51153 51161 51165 51177 51179 51191 51199 51510
#  51550 51650 51680 51700 51710 51760 51770 51810 53000 53005 53011 53015
#  53029 53033 53035 53041 53045 53053 53057 53061 53063 53067 53073 53077
#  54000 54003 54011 54033 54037 54039 54049 54055 54061 54079 54081 54107
#  55000 55009 55025 55027 55059 55063 55071 55073 55079 55087 55101 55105
#  55109 55111 55117 55133 55139 56000 56021 56025 21227 26055 36043 40147
#  48409  1001 35045 40037 51740 12107 20169 24017 37037  4005 45031 24037
#  26067 35061 51800 20155 37105 42103 55141 13095 50025 55055 37171 28035
#  45021 12089 38035 41071 39139 21151 13031  1055 12023 42015]

# %%
import pandas as pd

# Load FIPS reference
fips_df = pd.read_excel("US_FIPS_codes.xlsx", dtype=str)

# Ensure FIPS codes in the reference table are correctly padded
fips_df["FIPS State"] = fips_df["FIPS State"].str.zfill(2)
fips_df["FIPS County"] = fips_df["FIPS County"].str.zfill(3)

# Ensure geo_value is a 5-digit zero-padded string
df["geo_value"] = df["geo_value"].astype(str).str.zfill(5)

# Extract FIPS State and FIPS County from geo_value
df["FIPS State"] = df["geo_value"].str[:2]
df["FIPS County"] = df["geo_value"].str[-3:]

# Step 1: Merge with full FIPS (State + County)
merged_df = df.merge(fips_df, on=["FIPS State", "FIPS County"], how="left")

# Step 2: Fallback merge on FIPS State to recover State names
fallback_state = fips_df[["FIPS State", "State"]].drop_duplicates()
merged_df = merged_df.merge(fallback_state, on="FIPS State", how="left", suffixes=('', '_fallback'))

# Use fallback State name where missing
merged_df["State"] = merged_df["State"].fillna(merged_df["State_fallback"])

# Clean up temporary column
merged_df.drop(columns=["State_fallback"], inplace=True)

# %%
merged_df.head()
# Out:
#   time_value geo_value  smoothed_wspent_time_1d  smoothed_wtested_14d  \
# 0   1/7/2021     01000                34.412959             12.541558
# 1   1/7/2021     01003                32.814153             10.189340
# 2   1/7/2021     01015                35.621311             14.591271
# 3   1/7/2021     01051                40.453615             14.164503
# 4   1/7/2021     01069                39.228766             10.103564
#
#    smoothed_wpublic_transit_1d  smoothed_wworried_become_ill  \
# 0                     1.464798                     65.771681
# 1                     1.270183                     61.516584
# 2                     6.594649                           NaN
# 3                     3.320922                     68.718538
# 4                     0.288897                     59.961036
#
#    smoothed_wvaccine_likely_govt_health  smoothed_wshop_1d  \
# 0                             22.086274          52.854667
# 1                             25.179399          51.160278
# 2                                   NaN          54.503711
# 3                             19.438763          54.948755
# 4                             23.065494          60.118290
#
#    smoothed_wtested_positive_14d  smoothed_wwork_outside_home_1d  \
# 0                      29.288429                       30.487852
# 1                            NaN                       28.384842
# 2                            NaN                       37.003522
# 3                            NaN                       37.637900
# 4                            NaN                       36.156326
#
#    smoothed_wothers_masked  smoothed_wcli  smoothed_wcovid_vaccinated  \
# 0                57.334785       3.244379                      2.6382
# 1                53.172285       1.199572                         NaN
# 2                      NaN       3.890709                         NaN
# 3                67.550815       3.284647                         NaN
# 4                55.995745       1.881970                         NaN
#
#    smoothed_wvaccine_likely_friends  smoothed_wrestaurant_1d  \
# 0                         28.469582                18.571266
# 1                         27.532881                23.406516
# 2                               NaN                20.974363
# 3                         30.223647                20.009477
# 4                         30.806929                16.574756
#
#    smoothed_wvaccine_likely_politicians  smoothed_wvaccine_likely_who  \
# 0                              9.482316                     24.962112
# 1                              8.933682                     28.864558
# 2                                   NaN                           NaN
# 3                              7.570250                     26.494057
# 4                             12.916249                     24.747620
#
#    smoothed_wwearing_mask  smoothed_wlarge_event_1d FIPS State FIPS County  \
# 0               84.311759                 12.627098         01         000
# 1               82.778220                 11.727249         01         003
# 2                     NaN                 13.255336         01         015
# 3               86.587182                 13.823318         01         051
# 4               85.825453                 10.258936         01         069
#
#      State County Name
# 0  Alabama         NaN
# 1  Alabama     Baldwin
# 2  Alabama     Calhoun
# 3  Alabama      Elmore
# 4  Alabama     Houston

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
null_state_rows = merged_df[merged_df["State"].isnull()]
print(null_state_rows[["FIPS State", "FIPS County", "geo_value"]])  # or add other columns as needed
# Out:
# Empty DataFrame
# Columns: [FIPS State, FIPS County, geo_value]
# Index: []

# %%
null_count = df["smoothed_wtested_positive_14d"].isnull().sum()
print(f"Number of rows with null 'smoothed_wtested_positive_14d': {null_count}")
# Out:
# Number of rows with null 'smoothed_wtested_positive_14d': 21632

# %%
# Count non-null entries
non_null_count = merged_df["smoothed_wtested_positive_14d"].notnull().sum()
print(f"Number of rows with non-null 'smoothed_wtested_positive_14d': {non_null_count}")
# Out:
# Number of rows with non-null 'smoothed_wtested_positive_14d': 3994

# %%
p14d_df = merged_df[merged_df["smoothed_wtested_positive_14d"].notnull()].copy()

# %%
p14d_df.head()
# Out:
#    time_value geo_value  smoothed_wspent_time_1d  smoothed_wtested_14d  \
# 0    1/7/2021     01000                34.412959             12.541558
# 15   1/7/2021     02000                31.031930             23.187988
# 19   1/7/2021     04000                33.894471             15.813525
# 21   1/7/2021     04013                30.674532             16.170044
# 23   1/7/2021     04019                30.489939             16.193151
#
#     smoothed_wpublic_transit_1d  smoothed_wworried_become_ill  \
# 0                      1.464798                     65.771681
# 15                     5.247612                     54.332976
# 19                     1.670934                     70.449040
# 21                     3.106310                     68.928567
# 23                     2.943076                     69.579201
#
#     smoothed_wvaccine_likely_govt_health  smoothed_wshop_1d  \
# 0                              22.086274          52.854667
# 15                             31.829591          52.948188
# 19                             30.601786          52.224064
# 21                             32.197435          50.983665
# 23                             36.636282          52.706816
#
#     smoothed_wtested_positive_14d  smoothed_wwork_outside_home_1d  \
# 0                       29.288429                       30.487852
# 15                       8.843686                       31.242179
# 19                      30.302464                       26.614385
# 21                      22.710935                       24.467235
# 23                      21.912277                       24.371077
#
#     smoothed_wothers_masked  smoothed_wcli  smoothed_wcovid_vaccinated  \
# 0                 57.334785       3.244379                    2.638200
# 15                65.756589       0.421245                   15.910167
# 19                64.266832       1.401254                    4.715310
# 21                84.360238       2.082898                    4.005679
# 23                87.764291       1.306140                    6.249659
#
#     smoothed_wvaccine_likely_friends  smoothed_wrestaurant_1d  \
# 0                          28.469582                18.571266
# 15                         29.240819                13.132258
# 19                         38.028305                18.465710
# 21                         34.448458                17.593056
# 23                         36.117471                13.814072
#
#     smoothed_wvaccine_likely_politicians  smoothed_wvaccine_likely_who  \
# 0                               9.482316                     24.962112
# 15                             10.050320                     33.168119
# 19                             11.358013                     33.428347
# 21                             11.658930                     38.405013
# 23                             14.057577                     42.917359
#
#     smoothed_wwearing_mask  smoothed_wlarge_event_1d FIPS State FIPS County  \
# 0                84.311759                 12.627098         01         000
# 15               82.025101                  9.231545         02         000
# 19               87.570662                  9.285851         04         000
# 21               92.846578                  9.364862         04         013
# 23               93.671275                  6.418342         04         019
#
#       State County Name  smoothed_wcli_lagged  \
# 0   Alabama         NaN                   NaN
# 15   Alaska         NaN                   NaN
# 19  Arizona         NaN              3.244379
# 21  Arizona    Maricopa              0.421245
# 23  Arizona        Pima              1.401254
#
#     smoothed_wpublic_transit_1d_lagged  smoothed_wcovid_vaccinated_lagged
# 0                                  NaN                                NaN
# 15                                 NaN                           2.638200
# 19                            1.464798                          15.910167
# 21                            5.247612                           4.715310
# 23                            1.670934                           4.005679

# %%
# Dictionary mapping feature to lag
lag_info = {
    "smoothed_wcli": 2,
    "smoothed_wpublic_transit_1d": 2,
    "smoothed_wcovid_vaccinated": 1,
    "smoothed_wvaccine_likely_friends": 14
}

# Apply the lag and create new columns
for feature, lag in lag_info.items():
    lagged_col_name = f"{feature}_lagged"
    p14d_df[lagged_col_name] = p14d_df[feature].shift(lag)

# %%
p14d_df.head()
# Out:
#    time_value geo_value  smoothed_wspent_time_1d  smoothed_wtested_14d  \
# 0    1/7/2021     01000                34.412959             12.541558
# 15   1/7/2021     02000                31.031930             23.187988
# 19   1/7/2021     04000                33.894471             15.813525
# 21   1/7/2021     04013                30.674532             16.170044
# 23   1/7/2021     04019                30.489939             16.193151
#
#     smoothed_wpublic_transit_1d  smoothed_wworried_become_ill  \
# 0                      1.464798                     65.771681
# 15                     5.247612                     54.332976
# 19                     1.670934                     70.449040
# 21                     3.106310                     68.928567
# 23                     2.943076                     69.579201
#
#     smoothed_wvaccine_likely_govt_health  smoothed_wshop_1d  \
# 0                              22.086274          52.854667
# 15                             31.829591          52.948188
# 19                             30.601786          52.224064
# 21                             32.197435          50.983665
# 23                             36.636282          52.706816
#
#     smoothed_wtested_positive_14d  smoothed_wwork_outside_home_1d  \
# 0                       29.288429                       30.487852
# 15                       8.843686                       31.242179
# 19                      30.302464                       26.614385
# 21                      22.710935                       24.467235
# 23                      21.912277                       24.371077
#
#     smoothed_wothers_masked  smoothed_wcli  smoothed_wcovid_vaccinated  \
# 0                 57.334785       3.244379                    2.638200
# 15                65.756589       0.421245                   15.910167
# 19                64.266832       1.401254                    4.715310
# 21                84.360238       2.082898                    4.005679
# 23                87.764291       1.306140                    6.249659
#
#     smoothed_wvaccine_likely_friends  smoothed_wrestaurant_1d  \
# 0                          28.469582                18.571266
# 15                         29.240819                13.132258
# 19                         38.028305                18.465710
# 21                         34.448458                17.593056
# 23                         36.117471                13.814072
#
#     smoothed_wvaccine_likely_politicians  smoothed_wvaccine_likely_who  \
# 0                               9.482316                     24.962112
# 15                             10.050320                     33.168119
# 19                             11.358013                     33.428347
# 21                             11.658930                     38.405013
# 23                             14.057577                     42.917359
#
#     smoothed_wwearing_mask  smoothed_wlarge_event_1d FIPS State FIPS County  \
# 0                84.311759                 12.627098         01         000
# 15               82.025101                  9.231545         02         000
# 19               87.570662                  9.285851         04         000
# 21               92.846578                  9.364862         04         013
# 23               93.671275                  6.418342         04         019
#
#       State County Name  smoothed_wcli_lagged  \
# 0   Alabama         NaN                   NaN
# 15   Alaska         NaN                   NaN
# 19  Arizona         NaN              3.244379
# 21  Arizona    Maricopa              0.421245
# 23  Arizona        Pima              1.401254
#
#     smoothed_wpublic_transit_1d_lagged  smoothed_wcovid_vaccinated_lagged  \
# 0                                  NaN                                NaN
# 15                                 NaN                           2.638200
# 19                            1.464798                          15.910167
# 21                            5.247612                           4.715310
# 23                            1.670934                           4.005679
#
#     smoothed_wvaccine_likely_friends_lagged
# 0                                       NaN
# 15                                      NaN
# 19                                      NaN
# 21                                      NaN
# 23                                      NaN

# %%
row_count = len(p14d_df)
row_count
# Out:
# 3994

# %%
p14d_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3994 entries, 0 to 25611
# Data columns (total 27 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   time_value                               3994 non-null   object
#  1   geo_value                                3994 non-null   object
#  2   smoothed_wspent_time_1d                  3873 non-null   float64
#  3   smoothed_wtested_14d                     3879 non-null   float64
#  4   smoothed_wpublic_transit_1d              3873 non-null   float64
#  5   smoothed_wworried_become_ill             3903 non-null   float64
#  6   smoothed_wvaccine_likely_govt_health     3903 non-null   float64
#  7   smoothed_wshop_1d                        3873 non-null   float64
#  8   smoothed_wtested_positive_14d            3994 non-null   float64
#  9   smoothed_wwork_outside_home_1d           3873 non-null   float64
#  10  smoothed_wothers_masked                  3899 non-null   float64
#  11  smoothed_wcli                            3859 non-null   float64
#  12  smoothed_wcovid_vaccinated               3894 non-null   float64
#  13  smoothed_wvaccine_likely_friends         3903 non-null   float64
#  14  smoothed_wrestaurant_1d                  3873 non-null   float64
#  15  smoothed_wvaccine_likely_politicians     3904 non-null   float64
#  16  smoothed_wvaccine_likely_who             3906 non-null   float64
#  17  smoothed_wwearing_mask                   3899 non-null   float64
#  18  smoothed_wlarge_event_1d                 3873 non-null   float64
#  19  FIPS State                               3994 non-null   object
#  20  FIPS County                              3994 non-null   object
#  21  State                                    3994 non-null   object
#  22  County Name                              2321 non-null   object
#  23  smoothed_wcli_lagged                     3857 non-null   float64
#  24  smoothed_wpublic_transit_1d_lagged       3871 non-null   float64
#  25  smoothed_wcovid_vaccinated_lagged        3893 non-null   float64
#  26  smoothed_wvaccine_likely_friends_lagged  3889 non-null   float64
# dtypes: float64(21), object(6)
# memory usage: 873.7+ KB

# %%
# Fill NaN values in numeric columns with their median
p14d_m_df = p14d_df.copy()  # Optional: avoid changing original

# Only apply to numeric columns
numeric_cols = p14d_m_df.select_dtypes(include=["number"]).columns

# Fill NaNs with median for each numeric column
p14d_m_df[numeric_cols] = p14d_m_df[numeric_cols].fillna(p14d_m_df[numeric_cols].median())

# %%
p14d_m_df.isnull().sum()
# Out:
# time_value                                    0
# geo_value                                     0
# smoothed_wspent_time_1d                       0
# smoothed_wtested_14d                          0
# smoothed_wpublic_transit_1d                   0
# smoothed_wworried_become_ill                  0
# smoothed_wvaccine_likely_govt_health          0
# smoothed_wshop_1d                             0
# smoothed_wtested_positive_14d                 0
# smoothed_wwork_outside_home_1d                0
# smoothed_wothers_masked                       0
# smoothed_wcli                                 0
# smoothed_wcovid_vaccinated                    0
# smoothed_wvaccine_likely_friends              0
# smoothed_wrestaurant_1d                       0
# smoothed_wvaccine_likely_politicians          0
# smoothed_wvaccine_likely_who                  0
# smoothed_wwearing_mask                        0
# smoothed_wlarge_event_1d                      0
# FIPS State                                    0
# FIPS County                                   0
# State                                         0
# County Name                                1673
# smoothed_wcli_lagged                          0
# smoothed_wpublic_transit_1d_lagged            0
# smoothed_wcovid_vaccinated_lagged             0
# smoothed_wvaccine_likely_friends_lagged       0
# dtype: int64

# %%
p14d_m_df.to_csv("merged_fips_median_data.csv", index=False)

# %%
# Make a copy to preserve the original
p14d_sm_df = p14d_df.copy()

# Identify numeric columns
numeric_cols = p14d_sm_df.select_dtypes(include=["number"]).columns

# Group by 'County Name' and apply median fill for each group
p14d_sm_df[numeric_cols] = (
    p14d_sm_df
    .groupby("FIPS State")[numeric_cols]
    .transform(lambda col: col.fillna(col.median()))
)

# Step 2: Fill any remaining NaNs with the overall median of each column
p14d_sm_df[numeric_cols] = p14d_sm_df[numeric_cols].fillna(p14d_sm_df[numeric_cols].median())

# %%
# Out:
# time_value                                 0
# geo_value                                  0
# smoothed_wspent_time_1d                    0
# smoothed_wtested_14d                       0
# smoothed_wpublic_transit_1d                0
# smoothed_wworried_become_ill               0
# smoothed_wvaccine_likely_govt_health       0
# smoothed_wshop_1d                          0
# smoothed_wtested_positive_14d              0
# smoothed_wwork_outside_home_1d             0
# smoothed_wothers_masked                    0
# smoothed_wcli                              0
# smoothed_wcovid_vaccinated                 0
# smoothed_wvaccine_likely_friends           0
# smoothed_wrestaurant_1d                    0
# smoothed_wvaccine_likely_politicians       0
# smoothed_wvaccine_likely_who               0
# smoothed_wwearing_mask                     0
# smoothed_wlarge_event_1d                   0
# FIPS State                                 0
# FIPS County                                0
# State                                      0
# County Name                             1673
# dtype: int64

# %%
p14d_sm_df.to_csv("merged_fips_median_byState_bytotal_data.csv", index=False)

# %%
# Make a copy to preserve the original
p14d_movingaverage_df = p14d_df.copy()

# Step 1: Convert time_value to datetime if not already
p14d_movingaverage_df["time_value"] = pd.to_datetime(p14d_movingaverage_df["time_value"])

# Step 2: Sort by time_value
p14d_movingaverage_df = p14d_movingaverage_df.sort_values("time_value")

# Step 3: Identify numeric columns
numeric_cols = p14d_movingaverage_df.select_dtypes(include=["number"]).columns

# Step 4: Apply rolling average across entire DataFrame
# Note: Reset index to allow proper rolling based on time
p14d_movingaverage_df = p14d_movingaverage_df.set_index("time_value")

# Apply 7-day rolling mean to all numeric columns (window in days, not rows)
p14d_movingaverage_df = p14d_movingaverage_df.copy()
p14d_movingaverage_df[numeric_cols] = (
    p14d_movingaverage_df[numeric_cols]
    .rolling(window="7D", min_periods=1)
    .mean()
)

# Reset index to restore time_value as a column
p14d_movingaverage_df = p14d_movingaverage_df.reset_index()

# %%
p14d_movingaverage_df.isnull().sum()
# Out:
# time_value                                    0
# geo_value                                     0
# smoothed_wspent_time_1d                       0
# smoothed_wtested_14d                          0
# smoothed_wpublic_transit_1d                   0
# smoothed_wworried_become_ill                  0
# smoothed_wvaccine_likely_govt_health          0
# smoothed_wshop_1d                             0
# smoothed_wtested_positive_14d                 0
# smoothed_wwork_outside_home_1d                0
# smoothed_wothers_masked                       0
# smoothed_wcli                                 0
# smoothed_wcovid_vaccinated                    0
# smoothed_wvaccine_likely_friends              0
# smoothed_wrestaurant_1d                       0
# smoothed_wvaccine_likely_politicians          0
# smoothed_wvaccine_likely_who                  0
# smoothed_wwearing_mask                        0
# smoothed_wlarge_event_1d                      0
# FIPS State                                    0
# FIPS County                                   0
# State                                         0
# County Name                                1673
# smoothed_wcli_lagged                          1
# smoothed_wpublic_transit_1d_lagged            1
# smoothed_wcovid_vaccinated_lagged             1
# smoothed_wvaccine_likely_friends_lagged       1
# dtype: int64

# %%
p14d_movingaverage_df.to_csv("merged_fips_moving_average_data.csv", index=False)
